# %%
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import requests
import random
import os

#for Wen Wei Po they don't storge the date in the url, so just change the day mamual in the pop up window.

# %%
direct = "wenweipo/"

# %%
proxy_address = "brd.superproxy.io"
proxy_port = 22225
proxy_username = "brd-customer-hl_4abea413-zone-data_center"
proxy_password = "lmz4ftfwixm4"

proxy_options = {
    'proxy': {
        'http': f'http://{proxy_username}:{proxy_password}@{proxy_address}:{proxy_port}',
        'https': f'https://{proxy_username}:{proxy_password}@{proxy_address}:{proxy_port}',
        'request_interceptor': True,
        'response_interceptor': True,
        'no_proxy': 'localhost,127.0.0.1'  # Optional: Exclude certain URLs from proxying
    }
}

chrome_options = Options()
chrome_options.add_argument("--blink-settings=imagesEnabled=false")

driver = webdriver.Chrome()

# %%
url = "https://www.wenweipo.com/todaywenwei"
driver.get(url)

# %%
date = "2021-02-02"

# %%
click_element = driver.find_element(By.CSS_SELECTOR, "div.searchMore.da-bre")

driver.implicitly_wait(1)

time.sleep(5)

click_element.click()

time.sleep(10)

while (driver.find_element(By.CSS_SELECTOR, "div.searchMore.da-bre").find_element(By.CSS_SELECTOR, "a").text == "加載更多"):
    click_element = driver.find_element(By.CSS_SELECTOR, "div.searchMore.da-bre")

    driver.implicitly_wait(1)

    time.sleep(5)

    click_element.click()

    time.sleep(10)
# Out:
# Exception ignored in: <function Service.__del__ at 0x0000018FE1F1C540>
# Traceback (most recent call last):
#   File "C:\Users\walte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\common\service.py", line 185, in __del__
#     self.stop()
#   File "C:\Users\walte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\common\service.py", line 146, in stop
#     self.send_remote_shutdown_command()
#   File "C:\Users\walte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\common\service.py", line 131, in send_remote_shutdown_command
#     if not self.is_connectable():
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\walte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\common\service.py", line 120, in is_connectable
#     return utils.is_connectable(self.port)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\walte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\common\utils.py", line 101, in is_connectable
#     socket_ = socket.create_connection((host, port), 1)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\socket.py", line 843, in create_connection
#     exceptions.clear()  # raise only the last error
#     ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# c:\Users\walte\Documents\CCGL9011\wenweipo.ipynb Cell 6 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/walte/Documents/CCGL9011/wenweipo.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> driver.implicitly_wait(1)
#       <a href='vscode-notebook-cell:/c%3A/Users/walte/Documents/CCGL9011/wenweipo.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> time.sleep(5)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/walte/Documents/CCGL9011/wenweipo.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> click_element.click()
#       <a href='vscode-notebook-cell:/c%3A/Users/walte/Documents/CCGL9011/wenweipo.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> time.sleep(10)
#      <a href='vscode-notebook-cell:/c%3A/Users/walte/Documents/CCGL9011/wenweipo.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> while (driver.find_element(By.CSS_SELECTOR, "div.searchMore.da-bre").find_element(By.CSS_SELECTOR, "a").text == "加載更多"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webelement.py:394, in WebElement._execute(self, command, params)
#     392     params = {}
#     393 params["id"] = self._id
# --> 394 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=118.0.5993.70)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7AA3C8EF2+54786]
# 	(No symbol) [0x00007FF7AA335612]
# 	(No symbol) [0x00007FF7AA1EA4FD]
# 	(No symbol) [0x00007FF7AA22CB85]
# 	(No symbol) [0x00007FF7AA2229CF]
# 	(No symbol) [0x00007FF7AA24BE6A]
# 	(No symbol) [0x00007FF7AA2222E6]
# 	(No symbol) [0x00007FF7AA24C080]
# 	(No symbol) [0x00007FF7AA264D02]
# 	(No symbol) [0x00007FF7AA24BC43]
# 	(No symbol) [0x00007FF7AA220941]
# 	(No symbol) [0x00007FF7AA221B84]
# 	GetHandleVerifier [0x00007FF7AA717F52+3524194]
# 	GetHandleVerifier [0x00007FF7AA76D800+3874576]
# 	GetHandleVerifier [0x00007FF7AA765D7F+3843215]
# 	GetHandleVerifier [0x00007FF7AA465086+694166]
# 	(No symbol) [0x00007FF7AA340A88]
# 	(No symbol) [0x00007FF7AA33CA94]
# 	(No symbol) [0x00007FF7AA33CBC2]
# 	(No symbol) [0x00007FF7AA32CC83]
# 	BaseThreadInitThunk [0x00007FF98139257D+29]
# 	RtlUserThreadStart [0x00007FF9829CAA78+40]

# %%
links = []
topics = []

# %%
soup = BeautifulSoup(driver.page_source, "html.parser")

soup
# Out:
# <html lang="zh-Hans-HK"><head><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style>
# <title>
#
#         文匯报 -
#         香港文匯網
#
#     </title>
# <meta content="" property="og:image"/>
# <meta content="文匯报 - 香港文匯網" property="og:title"/>
# <meta content="香港文匯網是面向香港社會各界的綜合性主流網站，以愛國愛港為宗旨，堅持「文以載道、匯則興邦」的理念和「包容、合作、創新、拓展」的準則，其權威性得到各界肯定和認同。" property="og:description"/>
# <meta content="https://www.wenweipo.com/todaywenwei" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="香港文匯網" property="og:site_name"/>
# <meta content="香港文匯網是面向香港社會各界的綜合性主流網站，以愛國愛港為宗旨，堅持「文以載道、匯則興邦」的理念和「包容、合作、創新、拓展」的準則，其權威性得到各界肯定和認同。" name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="今日文匯" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <script src="https://www.wenweipo.com/static/wenweipo/js/jquery-3.5.0.min.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/jquery.flexslider.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/jquery.cookie.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/lib.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/main.js?template=A2023030815" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/search.js?version=2023032017" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/jquery-ui.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/util.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/script.js" type="text/javascript"></script>
# <script charset="utf-8" rel="stylesheet" src="https://www.wenweipo.com/static/wenweipo/js/qrcode.min.js" type="text/javascript"></script>
# <script charset="utf-8" rel="stylesheet" src="https://www.wenweipo.com/static/wenweipo/js/moment.js" type="text/javascript"></script>
# <link href="https://www.wenweipo.com/static/wenweipo/css/style.css" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/style-3.css" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/main-hf.css?template=A2023052214" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/main.css?template=A2022090600" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/polls.css" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/search.css" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/iconfont.css" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/add-common.css" rel="stylesheet"/>
# <script src="https://www.wenweipo.com/static/wenweipo/js/Marquee.js" type="text/javascript"></script>
# <script charset="utf-8" rel="stylesheet" src="https://wwp-static.wenweipo.com/minici/drift.js" type="text/javascript"></script><script src="https://wwp-static.wenweipo.com/minici/fingrtprprint2.min.js" type="text/javascript"></script>
# <script charset="utf-8" rel="stylesheet" src="https://www.wenweipo.com/static/wenweipo/js/md-pub.js?version=2023030813" type="text/javascript"></script>
# <script charset="utf-8" rel="stylesheet" src="https://www.wenweipo.com/static/wenweipo/js/column.js?template=2023030916" type="text/javascript"></script>
# <link href="https://www.wenweipo.com/static/wenweipo/css/hot-words.css" rel="stylesheet"/>
# <base target="_blank"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/style-ie.css" rel="stylesheet"/>
# <script>
#         //<![CDATA[
#         window.onload = function () {
#           if(document.documentMode < 10){
#             var notAdapted= document.getElementById("not-adapted");
#             notAdapted.style.display="block";
#           }
#         }
#         //]]>
#       </script>
# <script charset="utf-8" rel="stylesheet" src="https://www.wenweipo.com/static/wenweipo/js/swiper.min.js" type="text/javascript"></script>
# <script src="https://www.wenweipo.com/static/wenweipo/js/laydate.js" type="text/javascript"></script><link href="https://www.wenweipo.com/static/wenweipo/js/theme/default/laydate.css?v=5.0.9" id="layuicss-laydate" rel="stylesheet"/>
# <link href="https://www.wenweipo.com/static/wenweipo/css/swiper.min.css" rel="stylesheet"/>
# <link charset="utf-8" href="https://www.wenweipo.com/static/wenweipo/css/pageCss/column-today-html.css?version=20220811" rel="stylesheet"/>
# <base target="_self"/>
# <meta content="" http-equiv="origin-trial"/></head>
# <body>
# <input id="playerUrl" type="hidden" value="https://player.wenweipo.com/video-player/player.html?src="/>
# <input id="channelId" name="channelId" type="hidden" value="wenweipo"/>
# <input class="inputSearchFlag" type="hidden" value="0"/>
# <input class="userFlag" type="hidden" value="0"/>
# <span id="goTop"></span>
# <div id="not-adapted">
# <div>請使用下列任何一種瀏覽器瀏覽以達至最佳的用戶體驗：Google Chrome、Mozilla Firefox、Internet Explorer、Microsoft Edge 或Safari。</div>
# <div> 為避免使用網頁時發生問題，請確保你的網頁瀏覽器已更新至最新版本。</div>
# </div>
# <input class="includeSubColumn" name="includeSubColumn" type="hidden" value="true"/>
# <input class="inputColumnId" id="inputColumnId" type="hidden" value="5f47252ce4b0e87bc372692f"/>
# <input class="columnDirname" id="columnDirname" type="hidden" value="todaywenwei"/>
# <input class="inputParentId" id="inputParentId" type="hidden" value=""/>
# <input class="inputChildDirname" id="inputChildDirname" type="hidden" value="5f47252ce4b0e87bc372692f"/>
# <input class="columnUrl" id="columnUrl" type="hidden" value="https://www.wenweipo.com/todaywenwei"/>
# <input class="columnName" id="columnName" type="hidden" value="文匯报"/>
# <div class="global-percent">
# <div class="global-header-top">
# <div class="global-header-logo-date">
# <div class="global-header-logo">
# <h1>
# <a href="https://www.wenweipo.com">香港文匯網</a>
# </h1>
# </div>
# <div class="global-header-date">
# <div class="headerDate primary-header">
# <div class="date-box" style="width: auto; height: auto;">
# <div class="current-date">2023年10月15日 星期日</div>
# <div id="he-plugin-simple"><div class="weather-body" style=""><div class="weather-city module">香港</div><div class="weather-temp module">27°C</div><div class="weather-icon module"><img '="" alt="天气图片" src="https://wwp-static.wenweipo.com/img/weather/101.png" style="width: 24px; height: 24px; display: inline;"/></div><div class="weather-level module">無持續風向</div></div></div>
# </div>
# <div class="top-txt-icon">
# <img alt="人文載道,匯則興邦" src="https://wwp-static.wenweipo.com/img/icon/slogan-index.png" title="人文載道,匯則興邦"/>
# </div>
# </div>
# <script src="https://www.wenweipo.com/static/wenweipo//js/weather.js?v=20230908" type="text/javascript"></script>
# <style>
#               #he-plugin-simple div.s-sticker{
#                 padding:0px !important;
#               }
#               .site-footer{
#                 z-index: 999999;
#               }
#               .global-percent .date-box{
#                 width:160px;
#                 height:46px;
#               }
#               @media (min-width: 1366px){
#                 .top-txt-icon {
#                   margin-left: 30px;
#                 }
#               }
#             </style>
# </div>
# </div>
# <div class="global-header-banner" style="display: none;">
# <a href="https://www.wenweipo.com/dwsurvey/diaowen/elbxuwu.html" title="調查問卷">
# <img alt="調查問卷" src="https://wwp-static.wenweipo.com/img/newsImg/wenwei-survey.jpg" title="調查問卷"/>
# </a>
# </div>
# <div class="global-header-btn">
# <div class="header-search">
# <form action="https://search2.wenweipo.com/search" class="searchForm" id="header-search-form" method="get" style="overflow: inherit;">
# <button class="" style="margin-right:10px;border:none;outline: none;">
# <img alt="檢索" src="https://wwp-static.wenweipo.com/img/icon/search-icon-hs.png" style="width:14px;" title="檢索"/>
# </button>
# <div class="completion-words-block" style="display: none;">
# </div>
# <script>/*<![CDATA[*/
#        {
#          let hotWordsId = 'header-search-form';
#          $("#"+hotWordsId).css("overflow","inherit");
#          let hotWordsUlr = "https://search2.wenweipo.com/rest/topWords";
#          $.ajax({
#      		type:"get",
#      		url: encodeURI(hotWordsUlr),
#          }).done(function(result,status,xhr){
#           if(result && result.length>0){
#             let len = result.length;
#             for(let i=0; i<len;i++){
#               $("#"+hotWordsId+" .hot-words-block-items").append("<div class='hot-word-item'>" + result[i] + "</div>")
#               $(".mobile-search-page .hot-words-block-items").append("<div class='hot-word-item'>" + result[i] + "</div>")
#             }
#           }
#          });
#          $("#"+hotWordsId).on("focus","input",function(){
#            let hotWordId=$(this).parent().attr("id");
#            let value = $(this).val();
#            if(value == ""){
#            $(".hot-words-block").hide();
#
#            $("#"+hotWordId+" .hot-words-block").show();
#            }
#           });
#          $("#"+hotWordsId).on("blur","input",function(){
#            let hotWordId=$(this).parent().attr("id");
#
#            $(".hot-words-block").hide();
#            $(".completion-words-block").hide();
#           });
#          $("#"+hotWordsId).on("keyup","input",function(){
#            let hotWordId=$(this).parent().attr("id");
#
#            let value = $(this).val();
#
#            if(value==""){
#              $(".hot-words-block").hide();
#              $("#"+hotWordId+" .hot-words-block").show();
#              $(".completion-words-block").hide();
#            } else {
#              let completionWordsUlr="https://search2.wenweipo.com/rest/suggest?size=10&word="+ value;
#              $.ajax({
#                type:"get",
#                url: encodeURI(completionWordsUlr),
#              }).done(function(result,status,xhr){
#                if(result && result.length>0){
#                  let len = result.length;
#                  let html="";
#                  for(let i=0; i<len;i++){
#                   html+="<div class='completion-words-items'>";
#                   html+="<div class='completion-word-item'>" + result[i] + "</div>";
#                   html+="</div>";
#                  }
#                  $("#"+hotWordsId+" .completion-words-block").html(html);
#                  $(".hot-words-block").hide();
#                  $(".completion-words-block").hide();
#                  $("#"+hotWordId+" .completion-words-block").show();
#                } else {
#
#
#
#
#                }
#              });
#            }
#          });
#          $("#"+hotWordsId).on("mousedown",".hot-word-item",function(){
#            let hotWord = $(this).text();
#            if($(window).width() > 768){
#              $("input[name='query']").val(hotWord);
#              $("#"+hotWordsId).submit();
#            }else{
#              $("input[name='query']").val(hotWord);
#              $(".hot-words-block").hide();
#              $(".completion-words-block").hide();
#              searchStoryBut(this,2);
#            }
#
#
#
#          });
#          $("#"+hotWordsId).on("mousedown",".completion-word-item",function(){
#            let hotWord = $(this).text();
#            $("input[name='query']").val(hotWord);
#            $("#"+hotWordsId).submit();
#
#          });
#          $(".hotSearch-body").on("mousedown",".hot-word-item",function(){
#            let hotWord = $(this).text();
#            if($(window).width() > 768){
#              $("input[name='query']").val(hotWord);
#              $("#"+hotWordsId).submit();
#            }else{
#              $("input[name='query']").val(hotWord);
#              $(".hot-words-block").hide();
#              $(".completion-words-block").hide();
#              searchStoryBut(this,2);
#            }
#
#          });
#        }
#        /*]]>*/
#     </script>
# <input autocomplete="off" class="headerTopInput" id="hot-words-input" name="query" oninput="OnInput (event)" placeholder="請輸入關鍵詞" type="text_content"/>
# <button class="icon searchbutton" onclick="searchMiNiCi()">
# <span>搜索</span>
# </button>
# <span class="clearTxt iconfont" onclick="clearfn()" style="display: none;"></span>
# </form>
# </div>
# <div class="global-header-btn-paper displayNone">
# <div class="icon">
# <img alt="文匯報" src="https://wwp-static.wenweipo.com/img/icon/whb-paper.png" title="文匯報"/>
# </div>
# <div class="text">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp" title="文匯報">文匯報</a>
# </div>
# </div>
# <div class="global-header-btn-other displayNone">
# <div class="icon">
# <img alt="海外版" src="https://wwp-static.wenweipo.com/img/icon/header-hw.png" title="海外版"/>
# </div>
# <div class="text">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp-os" title="海外版">海外版</a>
# </div>
# </div>
# </div>
# <div class="user-div">
# <div class="mobile mobile-search">
# <img alt="檢索" src="https://wwp-static.wenweipo.com/img/icon/search-mobile.png" title="檢索"/>
# </div>
# <div class="mobile blue-bar-login white-bar-login">
# <a class="nologIn" href="/ucs/login/index" title="登入">
# <img alt="登入" src="https://wwp-static.wenweipo.com/img/icon/user-mobile.png" title="登入"/>
# </a>
# <div class="username">
# <a href="javascript:void(0);" id="showUserName" onclick="showUserNameClick();" target="_self" title="用戶名">
# <span class="spanIcon" id="span_none" style="">
# <img alt="" class="userImg" id="userImg"/>
# </span>
# </a>
# <div class="loginOut_center" style="display: none;">
# <ul>
# <a href="javascript:void(0);" onclick="showMemberCenterBtn()" target="_self" title="個人中心">個人中心</a>
# </ul>
# <ul>
# <a href="javascript:void(0);" onclick="showLogoutBtn()" target="_self" title="退出登錄">退出登錄</a>
# </ul>
# </div>
# </div>
# </div>
# <div class="mobile mobile-hamburm">
# <button onclick="showColumnMoreMenu()">
# <img alt="顯示更多" class="columnMore" src="https://wwp-static.wenweipo.com/img/icon/hamburg.png" title="顯示更多"/>
# </button>
# </div>
# </div>
# </div>
# <div class="mobile mobile-search-page">
# <div class="mobile mobile-search-page-header">
# <input autocomplete="off" class="headerTopInput" id="hot-words-input" name="query" placeholder="請輸入關鍵詞" type="text_content"/>
# <span class="icon" style="display:none !important;"></span>
# </div>
# <div class="mobile hotSearch">
# <div class="hotSearch-title">
#             熱門搜尋:
#           </div>
# <div class="hotSearch-body">
# <div class="hot-words-block-items">
# <div class="hot-word-item">四點希望</div><div class="hot-word-item">港車北上</div><div class="hot-word-item">國安法3周年</div><div class="hot-word-item">大灣區</div><div class="hot-word-item">基本法</div><div class="hot-word-item">達沃斯論壇</div><div class="hot-word-item">月壤</div><div class="hot-word-item">二十三條立法</div><div class="hot-word-item">瓦格納</div><div class="hot-word-item">消費券</div><div class="hot-word-item">四點希望</div><div class="hot-word-item">港車北上</div><div class="hot-word-item">國安法3周年</div><div class="hot-word-item">大灣區</div><div class="hot-word-item">基本法</div><div class="hot-word-item">達沃斯論壇</div><div class="hot-word-item">月壤</div><div class="hot-word-item">二十三條立法</div><div class="hot-word-item">瓦格納</div><div class="hot-word-item">消費券</div></div>
# </div>
# </div>
# </div>
# </div>
# <link charset="utf-8" href="https://www.wenweipo.com/static/wenweipo/css/header-anniversary.css?version=202300916" rel="stylesheet"/>
# <header class="global-header global-header-75anniversary fixed">
# <div class="global-header-container" style="opacity: 1;">
# <div class="inner">
# <div class="header-wrapper">
# <div class="white-bar-logo">
# <img alt="logo" src="https://wwp-static.wenweipo.com/img/icon/logo.png" title="logo"/>
# </div>
# <div class="global-navigation">
# <ul class="menu flex-menu">
# <li class="navIndex" style="display:flex;">
# <a href="/" target="_self" title="首頁">首頁</a>
# </li>
# <li class="menu-item-has-children 5f0bb184bd8c6f283270ee3a">
# <a href="https://www.wenweipo.com/immed" target="_self" title="時事">
# <span>時事</span>
# <span class="img imgBg"></span>
# </a>
# <ul class="sub-menu">
# <li class="5f0bb1dcbd8c6f283270ee4f">
# <a href="https://www.wenweipo.com/immed/hongkong" target="_self" title="香港">香港</a>
# </li>
# <li class="5f0bb1a4bd8c6f283270ee4d">
# <a href="https://www.wenweipo.com/immed/inland" target="_self" title="神州">神州</a>
# </li>
# <li class="5f0bb1c8bd8c6f283270ee4e" style="border-bottom:none;">
# <a href="https://www.wenweipo.com/immed/world" target="_self" title="國際">國際</a>
# </li>
# </ul>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="menu-item-has-children 5f0bb174bd8c6f283270ee39">
# <a href="https://www.wenweipo.com/comment" target="_self" title="評論">
# <span>評論</span>
# <span class="img imgBg"></span>
# </a>
# <ul class="sub-menu">
# <li class="5f0bb916bd8c6f283270ee52">
# <a href="https://www.wenweipo.com/comment/editorial" target="_self" title="社評">社評</a>
# </li>
# <li class="5f0bb908bd8c6f283270ee51">
# <a href="https://www.wenweipo.com/comment/commentcomment" target="_self" title="評論">評論</a>
# </li>
# <li class="5f0bb8c9bd8c6f283270ee50" style="border-bottom:none;">
# <a href="https://www.wenweipo.com/comment/comeon" target="_self" title="來論">來論</a>
# </li>
# </ul>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="menu-item-has-children 5f0bb164bd8c6f283270ee38">
# <a href="https://www.wenweipo.com/video" target="_self" title="視頻">
# <span>視頻</span>
# <span class="img imgBg"></span>
# </a>
# <ul class="sub-menu">
# <li class="5f0bb970bd8c6f283270ee55">
# <a href="https://www.wenweipo.com/video/videonews" target="_self" title="新聞">新聞</a>
# </li>
# <li class="5f0bb967bd8c6f283270ee54">
# <a href="https://www.wenweipo.com/video/interview" target="_self" title="訪談">訪談</a>
# </li>
# <li class="5f0bb950bd8c6f283270ee53" style="border-bottom:none;">
# <a href="https://www.wenweipo.com/video/living" target="_self" title="直播">直播</a>
# </li>
# </ul>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="menu-item-has-children 5f0bb14abd8c6f283270ee37">
# <a href="https://www.wenweipo.com/gallery" target="_self" title="圖集">
# <span>圖集</span>
# <span class="img imgBg"></span>
# </a>
# <ul class="sub-menu">
# <li class="5f0bb9d1bd8c6f283270ee58">
# <a href="https://www.wenweipo.com/gallery/currentaffairs" target="_self" title="香港">香港</a>
# </li>
# <li class="5f0bb9c0bd8c6f283270ee57">
# <a href="https://www.wenweipo.com/gallery/society" target="_self" title="神州">神州</a>
# </li>
# <li class="5f0bb9a1bd8c6f283270ee56" style="border-bottom:none;">
# <a href="https://www.wenweipo.com/gallery/entertainment" target="_self" title="國際">國際</a>
# </li>
# </ul>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="menu-item-has-children 64d9d6d8e4b0fb87b5425162">
# <a href="https://www.wenweipo.com/bayareapeople" target="_self" title="灣區人">
# <span>灣區人</span>
# <span class="img imgBg"></span>
# </a>
# <ul class="sub-menu">
# <li class="64d9d735e4b0fb87b5425165">
# <a href="https://www.wenweipo.com/bayareapeople/bayareaenterprises" target="_self" title="灣區企業">灣區企業</a>
# </li>
# <li class="64d9d775e4b0fb87b5425178">
# <a href="https://www.wenweipo.com/bayareapeople/bayareaculture" target="_self" title="灣區文化">灣區文化</a>
# </li>
# <li class="64d9d79fe4b0fb87b5425179">
# <a href="https://www.wenweipo.com/bayareapeople/bayareatourism" target="_self" title="灣區旅遊">灣區旅遊</a>
# </li>
# <li class="64d9d7d9e4b0fb87b542517a">
# <a href="https://www.wenweipo.com/bayareapeople/bayareapolicy" target="_self" title="灣區政策">灣區政策</a>
# </li>
# <li class="64d9d812e4b0fb87b542518d">
# <a href="https://www.wenweipo.com/bayareapeople/bayareatalent" target="_self" title="灣區人才">灣區人才</a>
# </li>
# <li class="60b0b0dbe4b0a46dabec50a6">
# <a href="https://www.wenweipo.com/bayareapeople/bayareaservices" target="_self" title="灣區服務易">灣區服務易</a>
# </li>
# </ul>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="5f0bb129bd8c6f283270ee36">
# <a href="https://www.wenweipo.com/spec" target="_self" title="專題">專題</a>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="5f0bb0e3bd8c6f283270ee33">
# <a href="https://www.wenweipo.com/specialcolumn" target="_self" title="專欄">專欄</a>
# </li>
# <script>
#                       //<![CDATA[
#                       //]]>
#                     </script>
# <li class="menu-ohter">
# <a href="https://www.wenweipo.com/todaywenwei" rel="noopener" title="文匯報">文匯報</a>
# </li>
# <li class="menu-ohter">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp" title="電子報">電子報</a>
# </li>
# <li class="menu-ohter">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp-os" title="海外報">海外版</a>
# </li>
# <li class="menu-ohter">
# <a href="http://so.wenweipo.com/" title="資料檢索">資料檢索</a>
# </li>
# </ul>
# </div>
# <div class="global-nav-search-bar">
# <form action="https://search2.wenweipo.com/search" class="searchForm" id="header-search-form-2" method="get" style="overflow: inherit;">
# <div class="hot-words-block" style="display: none;">
# <div class="hot-words-title">
# <div class="hot-words-title-img">
# <img alt="熱門搜尋" src="https://wwp-static.wenweipo.com/img/icon/hot-words.png" title="熱門搜尋"/>
# </div>
# <div class="hot-words-title-text">熱門搜尋：</div>
# </div>
# <div class="hot-words-block-items">
# <div class="hot-word-item">四點希望</div><div class="hot-word-item">港車北上</div><div class="hot-word-item">國安法3周年</div><div class="hot-word-item">大灣區</div><div class="hot-word-item">基本法</div><div class="hot-word-item">達沃斯論壇</div><div class="hot-word-item">月壤</div><div class="hot-word-item">二十三條立法</div><div class="hot-word-item">瓦格納</div><div class="hot-word-item">消費券</div></div>
# <s class="arrow-s"><i class="arrow-i"></i></s>
# </div>
# <div class="completion-words-block" style="display: none;">
# </div>
# <script>/*<![CDATA[*/
#        {
#          let hotWordsId = 'header-search-form-2';
#          $("#"+hotWordsId).css("overflow","inherit");
#          let hotWordsUlr = "https://search2.wenweipo.com/rest/topWords";
#          $.ajax({
#      		type:"get",
#      		url: encodeURI(hotWordsUlr),
#          }).done(function(result,status,xhr){
#           if(result && result.length>0){
#             let len = result.length;
#             for(let i=0; i<len;i++){
#               $("#"+hotWordsId+" .hot-words-block-items").append("<div class='hot-word-item'>" + result[i] + "</div>")
#               $(".mobile-search-page .hot-words-block-items").append("<div class='hot-word-item'>" + result[i] + "</div>")
#             }
#           }
#          });
#          $("#"+hotWordsId).on("focus","input",function(){
#            let hotWordId=$(this).parent().attr("id");
#            let value = $(this).val();
#            if(value == ""){
#            $(".hot-words-block").hide();
#
#            $("#"+hotWordId+" .hot-words-block").show();
#            }
#           });
#          $("#"+hotWordsId).on("blur","input",function(){
#            let hotWordId=$(this).parent().attr("id");
#
#            $(".hot-words-block").hide();
#            $(".completion-words-block").hide();
#           });
#          $("#"+hotWordsId).on("keyup","input",function(){
#            let hotWordId=$(this).parent().attr("id");
#
#            let value = $(this).val();
#
#            if(value==""){
#              $(".hot-words-block").hide();
#              $("#"+hotWordId+" .hot-words-block").show();
#              $(".completion-words-block").hide();
#            } else {
#              let completionWordsUlr="https://search2.wenweipo.com/rest/suggest?size=10&word="+ value;
#              $.ajax({
#                type:"get",
#                url: encodeURI(completionWordsUlr),
#              }).done(function(result,status,xhr){
#                if(result && result.length>0){
#                  let len = result.length;
#                  let html="";
#                  for(let i=0; i<len;i++){
#                   html+="<div class='completion-words-items'>";
#                   html+="<div class='completion-word-item'>" + result[i] + "</div>";
#                   html+="</div>";
#                  }
#                  $("#"+hotWordsId+" .completion-words-block").html(html);
#                  $(".hot-words-block").hide();
#                  $(".completion-words-block").hide();
#                  $("#"+hotWordId+" .completion-words-block").show();
#                } else {
#
#
#
#
#                }
#              });
#            }
#          });
#          $("#"+hotWordsId).on("mousedown",".hot-word-item",function(){
#            let hotWord = $(this).text();
#            if($(window).width() > 768){
#              $("input[name='query']").val(hotWord);
#              $("#"+hotWordsId).submit();
#            }else{
#              $("input[name='query']").val(hotWord);
#              $(".hot-words-block").hide();
#              $(".completion-words-block").hide();
#              searchStoryBut(this,2);
#            }
#
#
#
#          });
#          $("#"+hotWordsId).on("mousedown",".completion-word-item",function(){
#            let hotWord = $(this).text();
#            $("input[name='query']").val(hotWord);
#            $("#"+hotWordsId).submit();
#
#          });
#          $(".hotSearch-body").on("mousedown",".hot-word-item",function(){
#            let hotWord = $(this).text();
#            if($(window).width() > 768){
#              $("input[name='query']").val(hotWord);
#              $("#"+hotWordsId).submit();
#            }else{
#              $("input[name='query']").val(hotWord);
#              $(".hot-words-block").hide();
#              $(".completion-words-block").hide();
#              searchStoryBut(this,2);
#            }
#
#          });
#        }
#        /*]]>*/
#     </script>
# <input autocomplete="off" id="hot-words-input-2" name="query" placeholder="請輸入關鍵詞" type="text"/>
# <label for="header-search-form-2-submit" id="header-search-form-2-submit-label"></label>
# <input id="header-search-form-2-submit" style="display:none;" type="submit" value="submit"/>
# </form>
# <span class="icon show-search-input">
# <img alt="檢索" src="https://wwp-static.wenweipo.com/img/icon/search.png" style="width:14px;min-width:14px;object-fit: contain;" title="檢索"/>
# </span>
# </div>
# <div class="bar-dw-link">
# <div class="text">
# <a href="https://www.wenweipo.com/todaywenwei" rel="noopener" target="_self" title="文匯報">文匯報</a>
# </div>
# </div>
# <div class="bar-wenweipo-paper">
# <div class="icon">
# <img alt="電子報" src="https://wwp-static.wenweipo.com/img/icon/whb-paper.png" title="電子報"/>
# </div>
# <div class="text">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp" title="電子報">電子報</a>
# </div>
# </div>
# <div class="bar-haiwaiban">
# <div class="icon">
# <img alt="海外版" src="https://wwp-static.wenweipo.com/img/icon/header-hw.png" title="海外版"/>
# </div>
# <div class="text">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp-os" title="海外版">海外版</a>
# </div>
# </div>
# <div class="bar-wenweipo-old">
# <div class="text">
# <a href="http://so.wenweipo.com/" title="資料檢索">資料檢索</a>
# </div>
# </div>
# <div class="blue-bar-login white-bar-login">
# <a href="/ucs/login/index" title="登入">
# <img alt="登入" src="https://wwp-static.wenweipo.com/img/icon/user.png" title="登入"/>
# </a>
# </div>
# <div class="username">
# <a href="javascript:void(0);" id="showUserName" onclick="showUserNameClick();" target="_self" title="用戶名">
# <span class="spanIcon" id="span_none" style="">
# <img alt="" class="userImg" id="userImg"/>
# </span>
# </a>
# <div class="loginOut_center" style="display: none;">
# <ul>
# <a href="javascript:void(0);" onclick="showMemberCenterBtn()" target="_self" title="個人中心">個人中心</a>
# </ul>
# <ul>
# <a href="javascript:void(0);" onclick="showLogoutBtn()" target="_self" title="退出登錄">退出登錄</a>
# </ul>
# </div>
# </div>
# <style>
#                 .username{
#                   position:relative;
#                 }
#                 .loginOut_center{
#                   position:absolute;
#                   top:50px;
#                   background:#40434a;
#                   border-top: 4px solid #c21010;
#                   z-index:9999;
#                   right:0;
#                 }
#                 .loginOut_center ul{
#                   width:calc(4em + 20px);
#                   padding:10px;
#                 }
#                 .loginOut_center ul:last-child{
#                   padding-top:0;
#                 }
#                 .loginOut_center ul a{
#                   color:white;
#                 }
#               </style>
# <script>
#                 //<![CDATA[
#                 function searchMiNiCi(){
#                   mini_paq.push(["eventSearch", "search_keyword",$("input[name='query']").val(),{}]);
#                 }
#                 function showSearchInput(){
#                   var documentW = $(document).width();
#                   var searchFormW = "150px";
#                   if(documentW <= 650){
#                     searchFormW = "100px";
#                   }
#                   $(".header-wrapper .global-nav-search-bar #header-search-form-2").animate({
#                     width:searchFormW,
#                   },200);
#                   $(".show-search-input").css("display","none");
#                   document.getElementById('hot-words-input-2').focus();
#                 }
#                 $(document).bind("click",function(e){
#                   var target  = $(e.target);
#                   var targetClass = target.attr("class");
#                   if(target.closest(".show-search-input").length > 0){
#                     return false;
#                   }
#                   if(target.closest("#header-search-form-2").length > 0){
#
#                   }else if(target.closest("#header-search-form-2").length == 0 && target.attr("class") != 'show-search-input'){
#                     if($(window).width() < 650){
#                       $(".header-wrapper .global-nav-search-bar #header-search-form-2").animate({
#                         width:0,
#                       },200,function(){
#                         $(".show-search-input").css("display",'block');
#                       });
#                     }
#                   }
#                 });
#                 $(".show-search-input").bind("click",showSearchInput);
#                 $('#hot-words-input-2').bind('keydown', function (event) {
#                   var event = window.event || arguments.callee.caller.arguments[0];
#                   if (event.keyCode == 13){
#
#                     var queryName = $("#hot-words-input-2").val();
#                     $("input[name='query']").val(queryName);
#
#                   }
#                 });
#
#                 $('#hot-words-input').bind('keydown', function (event) {
#                   var event = window.event || arguments.callee.caller.arguments[0];
#                   if (event.keyCode == 13){
#
#                     var queryName = $("#hot-words-input").val();
#                     $("input[name='query']").val(queryName);
#                     mini_paq.push(["eventSearch", "search_keyword",queryName,{}]);
#
#                   }
#                 });
#                 $('.mobile.mobile-search-page-header .headerTopInput').bind('keydown', function (event) {
#                   var event = window.event || arguments.callee.caller.arguments[0];
#                   if (event.keyCode == 13){
#                     searchStoryBut($(".mobile.mobile-search-page-header span.icon"),0);
#                   }
#                 });
#
#                 $(document).ready(function () {
#                   var access_token = $.cookie('access_token');
#
#                   if(access_token=="" || access_token == null){
#                   }else{
#
#                     var Authorization = 'Bearer'+ access_token;
#                     $.ajax({
#                       type:'get',
#                       url: '/ucs/api/v1/private/profile',
#                       headers: {
#                         Authorization : Authorization,
#                         Accept: 'application/json; charset=utf-8',
#                       },
#                       dataType: "JSON",
#                       success:function(result,status){
#                         $(".white-bar-login").hide();
#                         var username = result.data.username;
#
#
#                         var uuid = result.data.uuid;
#                         $.cookie('uuid', uuid, { path: '/' });
#                         $.ajax({
#                           type:'get',
#                           url: '/ucs/api/v1/avatars/'+uuid+"?"+Math.random(),
#                           contentType:"application/x-www-form-urlencoded",
#                           success:function(result,status){
#                             $(".white-bar-login").hide();
#                             $('.username .userImg').attr('src', '/ucs/api/v1/avatars/'+uuid+"?"+Math.random());
#                             $('.username .userImg').attr('userid', uuid);
#                             $(".username .userImg").css({
#                               'width' : '30px',
#                               'height' : '30px',
#                               'border-radius' : '50%',
#                               'margin-top' : '4px'
#                             });
#                             $(".username .userImg").show();
#                             $("#span_none").show();
#                             $(".mobile.blue-bar-login.white-bar-login .nologIn").css("display","none");
#
#
#                             $(".mobile .username").css("display","block");
#                           },
#                           error:function(){
#                             $('.username .userImg').attr('src', "/static/wenweipo/img/user-hs.png");
#                             $(".username .userImg").css({
#                               'margin-top' : '18%',
#                               'width' : '30px',
#                               'height' : '30px',
#                               'border-radius' : '50%',
#                               'margin-top' : '10px'
#                             });
#                             $(".username .userImg").show();
#                             $("#span_none").show();
#                           }
#                         })
#                       },
#                       error:function(result,status){
#
#                       }
#                     })
#                   }
#                 });
#
#                 function showLogoutBtn(){
#                   var access_token = $.cookie('access_token');
#                   if(access_token=="" || access_token ==null){
#                     $(".username .userImg").hide();
#                     $("#span_none").hide();
#                     $(".loginImg").show();
#                     $(".login").show();
#                   }else{
#                     $.removeCookie('access_token',{ path: '/', domain: '.wenweipo.com' });
#                     $.removeCookie('username',{ path: '/', domain: '.wenweipo.com' });
#                     $.removeCookie('uuid',{ path: '/', domain: '.wenweipo.com' });
#
#
#                     <!--/*$.cookie('uuid','',{ path: '/'});*/-->
#
#                     $(".loginOut_center,.username").css("display","none");
#                     $(".nologIn").css("display","block");
#                     $(".white-bar-login").css("display","flex");
#                   }
#                 }
#
#                 function showMemberCenterBtn(){
#                   var access_token = $.cookie('access_token');
#                   if(access_token=="" || access_token ==null){
#                     $(".username .userImg").hide();
#                     $("#span_none").hide();
#                     $(".loginImg").show();
#                     $(".login").show();
#                   }else{
#                     $(".loginOut_center").hide();
#                     $(".userFlag").val(0);
#                     window.open("/ucs/center/main");
#                   }
#                 }
#
#                 $("#userLogin").click(function(){
#                   window.location.href="/ucs/login/index"
#                 });
#                 //]]>
#               </script>
# </div>
# </div>
# </div>
# <div class="headerRedLine">
# </div>
# </header>
# <div>
# <div class="subColumn">
# <div>
# <ul>
# <li class="5f3cf587e4b065db777ffe85"><a href="https://www.wenweipo.com/home" target="_self" title="首頁">首頁</a></li>
# <li class="5f0bb184bd8c6f283270ee3a"><a href="https://www.wenweipo.com/immed" target="_self" title="時事">時事</a></li>
# <li class="5f0bb174bd8c6f283270ee39"><a href="https://www.wenweipo.com/comment" target="_self" title="評論">評論</a></li>
# <li class="5f47252ce4b0e87bc372692f current-menu-item"><a href="https://www.wenweipo.com/todaywenwei" style="color: rgb(194, 16, 16);" target="_self" title="文匯报">文匯报</a></li>
# <li class="5f0bb06dbd8c6f283270ee32"><a href="https://www.wenweipo.com/hotspot" target="_self" title="熱點">熱點</a></li>
# <li class="5f0bb164bd8c6f283270ee38"><a href="https://www.wenweipo.com/video" target="_self" title="視頻">視頻</a></li>
# <li class="5f0bb14abd8c6f283270ee37"><a href="https://www.wenweipo.com/gallery" target="_self" title="圖集">圖集</a></li>
# <li class="64d9d6d8e4b0fb87b5425162"><a href="https://www.wenweipo.com/bayareapeople" target="_self" title="灣區人">灣區人</a></li>
# <li class="5f0bb129bd8c6f283270ee36"><a href="https://www.wenweipo.com/spec" target="_self" title="專題">專題</a></li>
# <li class="5f0bb113bd8c6f283270ee35"><a href="https://www.wenweipo.com/survey" target="_self" title="調查">調查</a></li>
# <li class="5f0bb0ffbd8c6f283270ee34"><a href="https://www.wenweipo.com/forum" target="_self" title="論壇">論壇</a></li>
# <li class="5f0bb0e3bd8c6f283270ee33"><a href="https://www.wenweipo.com/specialcolumn" target="_self" title="專欄">專欄</a></li>
# <li class="6088c4d3e4b0476859b8d909"><a href="https://www.wenweipo.com/interactive" target="_self" title="互動">互動</a></li>
# <li class="5fb4e3aee4b020344463dcf2"><a href="https://www.wenweipo.com/advertisement" target="_self" title="廣告">廣告</a></li>
# </ul>
# </div>
# <div class="clear"></div>
# <script>
#               //<![CDATA[
#               var columnId = $(".inputColumnId").val();
#               $(".subColumn ."+columnId + ">a").css("color","#C21010");
#               //]]>
#             </script>
# </div>
# </div>
# <div class="selectColumnMore">
# <div class="selectColumnMoreTitle">
# <div class="columnMoreClose">
# <button onclick="closeColumnMoreMenu()">
# <img alt="關閉欄目更多菜單" src="https://wwp-static.wenweipo.com/img/icon/close-column-more.png" title="關閉欄目更多菜單"/>
# </button>
# </div>
# <div class="titleName">
# </div>
# <div class="columnMoreClose">
# <button onclick="closeColumnMoreMenu()" style="display:none;">
# <img alt="關閉欄目更多菜單" src="https://wwp-static.wenweipo.com/img/icon/close.png" title="關閉欄目更多菜單"/>
# </button>
# </div>
# </div>
# <ul style="height:calc(100% - 36px);overflow:auto;">
# <li class="moreColumnParent">
# <a class="moreColumnIndex moreColumnCurrent" href="https://www.wenweipo.com" target="_self" title="首页">首页</a>
# </li>
# <li class="moreColumnParent">
# <a class="5f0bb184bd8c6f283270ee3a" href="https://www.wenweipo.com/immed" title="時事">時事</a>
# <ul>
# <li class="moreColumnChild">
# <a class="5f0bb1dcbd8c6f283270ee4f" href="https://www.wenweipo.com/immed/hongkong" title="- 香港">- 香港</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb1a4bd8c6f283270ee4d" href="https://www.wenweipo.com/immed/inland" title="- 神州">- 神州</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb1c8bd8c6f283270ee4e" href="https://www.wenweipo.com/immed/world" title="- 國際">- 國際</a>
# </li>
# </ul>
# </li>
# <li class="moreColumnParent">
# <a class="5f0bb174bd8c6f283270ee39" href="https://www.wenweipo.com/comment" title="評論">評論</a>
# <ul>
# <li class="moreColumnChild">
# <a class="5f0bb916bd8c6f283270ee52" href="https://www.wenweipo.com/comment/editorial" title="- 社評">- 社評</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb908bd8c6f283270ee51" href="https://www.wenweipo.com/comment/commentcomment" title="- 評論">- 評論</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb8c9bd8c6f283270ee50" href="https://www.wenweipo.com/comment/comeon" title="- 來論">- 來論</a>
# </li>
# </ul>
# </li>
# <li class="moreColumnParent">
# <a class="5f47252ce4b0e87bc372692f current-menu-item moreColumnCurrent" href="https://www.wenweipo.com/todaywenwei" title="文匯报">文匯报</a>
# </li>
# <li class="moreColumnParent">
# <a class="5f0bb164bd8c6f283270ee38" href="https://www.wenweipo.com/video" title="視頻">視頻</a>
# <ul>
# <li class="moreColumnChild">
# <a class="5f0bb970bd8c6f283270ee55" href="https://www.wenweipo.com/video/videonews" title="- 新聞">- 新聞</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb967bd8c6f283270ee54" href="https://www.wenweipo.com/video/interview" title="- 訪談">- 訪談</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb950bd8c6f283270ee53" href="https://www.wenweipo.com/video/living" title="- 直播">- 直播</a>
# </li>
# </ul>
# </li>
# <li class="moreColumnParent">
# <a class="5f0bb14abd8c6f283270ee37" href="https://www.wenweipo.com/gallery" title="圖集">圖集</a>
# <ul>
# <li class="moreColumnChild">
# <a class="5f0bb9d1bd8c6f283270ee58" href="https://www.wenweipo.com/gallery/currentaffairs" title="- 香港">- 香港</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb9c0bd8c6f283270ee57" href="https://www.wenweipo.com/gallery/society" title="- 神州">- 神州</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f0bb9a1bd8c6f283270ee56" href="https://www.wenweipo.com/gallery/entertainment" title="- 國際">- 國際</a>
# </li>
# </ul>
# </li>
# <li class="moreColumnParent">
# <a class="64d9d6d8e4b0fb87b5425162" href="https://www.wenweipo.com/bayareapeople" title="灣區人">灣區人</a>
# <ul>
# <li class="moreColumnChild">
# <a class="64d9d735e4b0fb87b5425165" href="https://www.wenweipo.com/bayareapeople/bayareaenterprises" title="- 灣區企業">- 灣區企業</a>
# </li>
# <li class="moreColumnChild">
# <a class="64d9d775e4b0fb87b5425178" href="https://www.wenweipo.com/bayareapeople/bayareaculture" title="- 灣區文化">- 灣區文化</a>
# </li>
# <li class="moreColumnChild">
# <a class="64d9d79fe4b0fb87b5425179" href="https://www.wenweipo.com/bayareapeople/bayareatourism" title="- 灣區旅遊">- 灣區旅遊</a>
# </li>
# <li class="moreColumnChild">
# <a class="64d9d7d9e4b0fb87b542517a" href="https://www.wenweipo.com/bayareapeople/bayareapolicy" title="- 灣區政策">- 灣區政策</a>
# </li>
# <li class="moreColumnChild">
# <a class="64d9d812e4b0fb87b542518d" href="https://www.wenweipo.com/bayareapeople/bayareatalent" title="- 灣區人才">- 灣區人才</a>
# </li>
# <li class="moreColumnChild">
# <a class="60b0b0dbe4b0a46dabec50a6" href="https://www.wenweipo.com/bayareapeople/bayareaservices" title="- 灣區服務易">- 灣區服務易</a>
# </li>
# </ul>
# </li>
# <li class="moreColumnParent">
# <a class="5f0bb129bd8c6f283270ee36" href="https://www.wenweipo.com/spec" title="專題">專題</a>
# <ul>
# <li class="moreColumnChild">
# <a class="5f4f2aafe4b006d9eaf623b2" href="https://www.wenweipo.com/spec/gatspecial" title="- 香港">- 香港</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f520409e4b006d9eaf63d52" href="https://www.wenweipo.com/spec/specinland" title="- 兩岸">- 兩岸</a>
# </li>
# <li class="moreColumnChild">
# <a class="5f520425e4b006d9eaf63d53" href="https://www.wenweipo.com/spec/specInternational" title="- 國際">- 國際</a>
# </li>
# </ul>
# </li>
# <li class="moreColumnParent">
# <a class="5f0bb0e3bd8c6f283270ee33" href="https://www.wenweipo.com/specialcolumn" title="專欄">專欄</a>
# <ul>
# </ul>
# </li>
# <li class="moreColumnParent">
# <div class="shareBtn">
# <a onclick="showWXimg()">
# <img alt="顯示微信圖片" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wx.png" title="顯示微信圖片"/>
# <img alt="顯示微信圖片" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wx-hover.png" title="顯示微信圖片"/>
# </a>
# <div class="wx-img" onclick="closeWXimg()" style="width:80px;">
# <img alt="關閉微信圖片" src="https://wwp-static.wenweipo.com/img/icon/wx-share.png" title="關閉微信圖片"/>
# </div>
# </div>
# <div class="shareBtn">
# <a href="https://zh-hk.facebook.com/wenweipo/">
# <img alt="分享" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-fb.png" title="分享"/>
# <img alt="分享" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-fb-hover.png" title="分享"/>
# </a>
# </div>
# <div class="shareBtn">
# <a href="https://weibo.com/wwpnet">
# <img alt="分享" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wb.png" title="分享"/>
# <img alt="分享" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wb-hover.png" title="分享"/>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="top-nav-box">
# <div class="top-nav">
# <ul class="today-ul">
# <li><a href="https://www.wenweipo.com/todaywenwei/whnews">要聞</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whcomment">評論</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whHK">香港</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whmainland">內地</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whTW">台灣</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whinternational">國際</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/economic">財經</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/investmentandfinancial">投資理財</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/financialhotspot">財經熱點</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whreading">讀書</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/wheducation">教育</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whentertainment">娛樂</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whphysicaleducation">體育</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/supplement">副刊</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/whespecially">特刊</a></li>
# <li><a href="https://www.wenweipo.com/todaywenwei/operaworld">戲曲天地</a></li>
# </ul>
# </div>
# </div>
# <div class="searchDiv" style="display: block;">
# <div class="searchSmallDiv">
# <div class="searchTitle_page">
# <input name="channelId" type="hidden" value="wenweipo"/>
# <input name="staticResource" type="hidden" value="/static/wenweipo/"/>
# <input name="searchSort" type="hidden" value="0"/>
# <input name="searchMatching" type="hidden" value="0"/>
# <input name="thisPageNum" type="hidden" value="21"/>
# <input name="keyWordWay" type="hidden" value="0"/>
# <input name="searchDateVal" type="hidden" value="2021-02-02"/>
# </div>
# <div class="searchOther">
# <div class="goBackLastPage">
# <button onclick="goback()">返回上一頁</button>
# </div>
# <div class="searchNumber" style="display: none;">找到约<font color="#C21010">0</font>条结果</div>
# <div class="searchCheckBox" style="display: none;">
# <div class="searchCheckChildren" id="sortOrder" style="position: relative;">
# <div style="text-align:center;cursor: pointer;">
# <div class="searchSort">
# <span id="selectedSortOrder">從新到舊</span>
# </div>
# <div class="searchSortImg">
# <img alt="圖標" src="https://wwp-static.wenweipo.com/img/icon/xiala.png" style=" margin-bottom: 3px;" title="圖標"/></div>
# </div>
# <div class="sortOrderOptions" id="sortOrderOptions" style="display: none;">
# <dl>
# <dt class="searchSelectOrder" id="sortOrderDesc" onclick="searchStorySetSortOrder(this);" text="從新到舊" value="0">從新到舊</dt>
# <dt class="" id="sortOrderAsc" onclick="searchStorySetSortOrder(this);" text="從舊到新" value="1">從舊到新</dt>
# <dt class="" id="sortOrderRelevant" onclick="searchStorySetSortOrder(this);" style="display:none;" text="相關度" value="2">相關度</dt>
# </dl>
# </div>
# </div>
# <div class="searchCheckChildren" id="matchingCondition" style="position: relative;">
# <div style="text-align:center;cursor: pointer;">
# <div class="searchSort">
# <snap id="selectedMatchingCondition">搜全文 </snap>
# </div>
# <div class="searchSortImg">
# <img alt="圖標" src="https://wwp-static.wenweipo.com/img/icon/xiala.png" style=" margin-bottom: 3px;" title="圖標"/>
# </div>
# </div>
# <div class="matchingConditionOptions" id="matchingConditionOptions" style="display: none;">
# ...
# <span class="title-line"></span>
# </h2>
# </div>
# <div class="content">
# <div class="line">
# <img alt="李家超：大力推動體育方向正確" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="李家超：大力推動體育方向正確"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af56be4b0fdf828a2b78d.html" title="李家超：大力推動體育方向正確">李家超：大力推動體育方向正確</a>
# </div>
# <div class="line">
# <img alt="壁球入奧  港將夢想成真添動力" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="壁球入奧  港將夢想成真添動力"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af55be4b0fdf828a2b78b.html" title="壁球入奧  港將夢想成真添動力">壁球入奧  港將夢想成真添動力</a>
# </div>
# <div class="line">
# <img alt="獎牌為電競正名  本地聯賽勢在必行" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="獎牌為電競正名  本地聯賽勢在必行"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af551e4b0fdf828a2b789.html" title="獎牌為電競正名  本地聯賽勢在必行">獎牌為電競正名  本地聯賽勢在必行</a>
# </div>
# <div class="line">
# <img alt="長話短說：崔浩然：杭州亞運令劍擊隊更強" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="長話短說：崔浩然：杭州亞運令劍擊隊更強"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af548e4b0fdf828a2b787.html" title="長話短說：崔浩然：杭州亞運令劍擊隊更強">長話短說：崔浩然：杭州亞運令劍擊隊更強</a>
# </div>
# <div class="line">
# <img alt="長話短說：將戰世錦賽  許得恩享受比賽" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="長話短說：將戰世錦賽  許得恩享受比賽"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af53de4b0fdf828a2b785.html" title="長話短說：將戰世錦賽  許得恩享受比賽">長話短說：將戰世錦賽  許得恩享受比賽</a>
# </div>
# <div class="line">
# <img alt="狂牛憂失威  未敢輕率" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="狂牛憂失威  未敢輕率"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3ade4b0fdf828a2b747.html" title="狂牛憂失威  未敢輕率">狂牛憂失威  未敢輕率</a>
# </div>
# <div class="line">
# <img alt="法 葡 比先過關   晉歐國盃決賽周" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="法 葡 比先過關   晉歐國盃決賽周"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3a3e4b0fdf828a2b746.html" title="法 葡 比先過關   晉歐國盃決賽周">法 葡 比先過關   晉歐國盃決賽周</a>
# </div>
# <div class="line">
# <img alt="楊曉威  謝恩  躋身香港高爾夫球公開賽" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="楊曉威  謝恩  躋身香港高爾夫球公開賽"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af399e4b0fdf828a2b745.html" title="楊曉威  謝恩  躋身香港高爾夫球公開賽">楊曉威  謝恩  躋身香港高爾夫球公開賽</a>
# </div>
# <div class="line">
# <img alt="屈堅斯獲重召即有「士哥」" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="屈堅斯獲重召即有「士哥」"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af38ee4b0fdf828a2b744.html" title="屈堅斯獲重召即有「士哥」">屈堅斯獲重召即有「士哥」</a>
# </div>
# <div class="line">
# <img alt="上海大師賽「費 娜 臻」同框" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="上海大師賽「費 娜 臻」同框"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af384e4b0fdf828a2b743.html" title="上海大師賽「費 娜 臻」同框">上海大師賽「費 娜 臻」同框</a>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="title">
# <h2 class="title-txt">
#                     副刊<a class="more" href="https://www.wenweipo.com/todaywenwei/supplement/" title="查看更多">更多</a>
# <span class="title-line"></span>
# </h2>
# </div>
# <div class="content">
# <div class="line">
# <img alt="魯迅的三次香港之行  「畏途」上直言不諱  啟發「新聲」" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="魯迅的三次香港之行  「畏途」上直言不諱  啟發「新聲」"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af4fde4b0fdf828a2b777.html" title="魯迅的三次香港之行  「畏途」上直言不諱  啟發「新聲」">魯迅的三次香港之行  「畏途」上直言不諱  啟發「新聲」</a>
# </div>
# <div class="line">
# <img alt="魯迅在香港已 「深入民心」" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="魯迅在香港已 「深入民心」"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af4ede4b0fdf828a2b775.html" title="魯迅在香港已 「深入民心」">魯迅在香港已 「深入民心」</a>
# </div>
# <div class="line">
# <img alt="張隆溪：有必要從現代人的角度再理解魯迅" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="張隆溪：有必要從現代人的角度再理解魯迅"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af4e4e4b0fdf828a2b773.html" title="張隆溪：有必要從現代人的角度再理解魯迅">張隆溪：有必要從現代人的角度再理解魯迅</a>
# </div>
# <div class="line">
# <img alt="特寫：魯迅橫眉冷對下的溫情一面" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="特寫：魯迅橫眉冷對下的溫情一面"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af4d9e4b0fdf828a2b771.html" title="特寫：魯迅橫眉冷對下的溫情一面">特寫：魯迅橫眉冷對下的溫情一面</a>
# </div>
# <div class="line">
# <img alt="新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3fce4b0fdf828a2b756.html" title="新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》">新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》</a>
# </div>
# <div class="line">
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3ece4b0fdf828a2b754.html" title="戲曲視窗：粵劇奇「景」（上）">戲曲視窗：粵劇奇「景」（上）</a>
# </div>
# <div class="line">
# <img alt="粵語長片粵劇《代代扭紋柴》的舞蹈" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="粵語長片粵劇《代代扭紋柴》的舞蹈"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3e9e4b0fdf828a2b752.html" title="粵語長片粵劇《代代扭紋柴》的舞蹈">粵語長片粵劇《代代扭紋柴》的舞蹈</a>
# </div>
# <div class="line">
# <img alt="《荊釵記》一場視聽盛宴" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="《荊釵記》一場視聽盛宴"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3dee4b0fdf828a2b750.html" title="《荊釵記》一場視聽盛宴">《荊釵記》一場視聽盛宴</a>
# </div>
# <div class="line">
# <img alt="戲曲進校園 經典共傳承" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="戲曲進校園 經典共傳承"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3d5e4b0fdf828a2b74e.html" title="戲曲進校園 經典共傳承">戲曲進校園 經典共傳承</a>
# </div>
# <div class="line">
# <img alt="舞台快訊" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="舞台快訊"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3cae4b0fdf828a2b74c.html" title="舞台快訊">舞台快訊</a>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="title">
# <h2 class="title-txt">
#                     戲曲天地 <a class="more" href="https://www.wenweipo.com/todaywenwei/operaworld/" title="查看更多">更多</a>
# <span class="title-line"></span>
# </h2>
# </div>
# <div class="content">
# <div class="line">
# <img alt="新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3fce4b0fdf828a2b756.html" title="新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》">新光薈萃折子戲專場有文有武  梁兆明伉儷演名劇《連城璧之釵刺》</a>
# </div>
# <div class="line">
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3ece4b0fdf828a2b754.html" title="戲曲視窗：粵劇奇「景」（上）">戲曲視窗：粵劇奇「景」（上）</a>
# </div>
# <div class="line">
# <img alt="粵語長片粵劇《代代扭紋柴》的舞蹈" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="粵語長片粵劇《代代扭紋柴》的舞蹈"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3e9e4b0fdf828a2b752.html" title="粵語長片粵劇《代代扭紋柴》的舞蹈">粵語長片粵劇《代代扭紋柴》的舞蹈</a>
# </div>
# <div class="line">
# <img alt="《荊釵記》一場視聽盛宴" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="《荊釵記》一場視聽盛宴"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3dee4b0fdf828a2b750.html" title="《荊釵記》一場視聽盛宴">《荊釵記》一場視聽盛宴</a>
# </div>
# <div class="line">
# <img alt="戲曲進校園 經典共傳承" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="戲曲進校園 經典共傳承"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3d5e4b0fdf828a2b74e.html" title="戲曲進校園 經典共傳承">戲曲進校園 經典共傳承</a>
# </div>
# <div class="line">
# <img alt="舞台快訊" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="舞台快訊"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3cae4b0fdf828a2b74c.html" title="舞台快訊">舞台快訊</a>
# </div>
# <div class="line">
# <img alt="香港電台第五台戲曲天地節目表" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="香港電台第五台戲曲天地節目表"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3c1e4b0fdf828a2b74a.html" title="香港電台第五台戲曲天地節目表">香港電台第五台戲曲天地節目表</a>
# </div>
# <div class="line">
# <img alt="香港電台第五台戲曲之夜節目表" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="香港電台第五台戲曲之夜節目表"/>
# <a href="https://www.wenweipo.com/a/202310/15/AP652af3b7e4b0fdf828a2b748.html" title="香港電台第五台戲曲之夜節目表">香港電台第五台戲曲之夜節目表</a>
# </div>
# <div class="line">
# <img alt="《經典折子戲》Part 2  11月新光登場  吳仟峰梁兆明梁非同好戲連場" src="https://wwp-static.wenweipo.com/img/icon/smail-icon.png" title="《經典折子戲》Part 2  11月新光登場  吳仟峰梁兆明梁非同好戲連場"/>
# <a href="https://www.wenweipo.com/a/202310/08/AP6521b941e4b0fdf828a1c703.html" title="《經典折子戲》Part 2  11月新光登場  吳仟峰梁兆明梁非同好戲連場">《經典折子戲》Part 2  11月新光登場  吳仟峰梁兆明梁非同好戲連場</a>
# </div>
# <div class="line">
# <a href="https://www.wenweipo.com/a/202310/08/AP6521b931e4b0fdf828a1c701.html" title="戲曲視窗：粵劇裏的海派文化細胞（九）">戲曲視窗：粵劇裏的海派文化細胞（九）</a>
# </div>
# </div>
# </div>
# </div>
# </main>
# <link charset="utf-8" href="https://www.wenweipo.com/static/wenweipo/css/footer-anniversary.css?version=20230909" rel="stylesheet"/>
# <div class="footer-share-box anniversary-footer-share-box">
# <div class="footer-logo-share">
# <div class="footer-logo">
# <div class="footerLogo">
# <img alt="底部logo" src="https://wwp-static.wenweipo.com/img/icon/footer-logo.png" title="底部logo"/>
# </div>
# <div class="footerText">
# <span>文以載道 匯則興邦</span>
# </div>
# </div>
# <div class="footer-logo-share-other">
# <div class="global-header-btn-paper">
# <div class="text">
# <a href="https://www.wenweipo.com/todaywenwei" rel="noopener" title="文匯報">文匯報</a>
# </div>
# </div>
# <div class="global-header-btn-paper">
# <div class="icon">
# <img alt="電子報" src="https://wwp-static.wenweipo.com/img/icon/whb-paper.png" style="width:16px;" title="電子報"/>
# </div>
# <div class="text">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp">電子報</a>
# </div>
# </div>
# <div class="global-header-btn-other global-header-btn-paper">
# <div class="icon" style="width:16px;">
# <img alt="海外版" src="https://wwp-static.wenweipo.com/img/icon/header-hw.png" title="海外版"/>
# </div>
# <div class="text">
# <a href="https://www.wenweipo.com/epaper/view/wwp/epaper?type=wwp-os" title="海外版">海外版</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-line-box">
# <div class="footer-line"></div>
# </div>
# <footer class="site-footer anniversary-site-footer">
# <div class="inner">
# <div class="footer-bottom">
# <div class="footer-bottom-left">
# <div class="footer-link">
# <a href="https://www.wenweipo.com/doc/contact_us.html" title="聯繫我們">聯繫我們</a>
# <a href="https://www.wenweipo.com/doc/ad_rate_2021_WWP.html" title="廣告服務">廣告服務</a>
# <span style="color:#fff;">文匯報訂閱</span>
# <a href="https://www.wenweipo.com/doc/privacy_agreement.html" title="隱私政策">隱私政策</a>
# <a href="https://www.wenweipo.com/doc/service_agreement.html" style="display:none;" title="服務條款">服務條款</a>
# <!--<div class="download-div">
#                   <a href="/share" title="App下載">App下載</a>
#                 </div>*-->
# </div>
# <div class="footer-copy">
# <div class="footerCopy">
# <span>香港大公文匯傳媒集團全媒體中心版權所有 </span>
# <span style="width:100%;">© 1997-2023 WENWEIPO.COM LIMITED.</span>
# </div>
# <div class="footerPrinter-group">
# <div class="footerPrinter">
#                     承印商：香港文匯報有限公司
#                   </div>
# <div class="footerPrinterAddr">
#                     地址：香港香港仔田灣海旁道7號興偉中心2-4樓
#                   </div>
# </div>
# </div>
# </div>
# <div class="footer-bottom-right">
# <div class="footerShare">
# <div class="footerShare-text">
#                   關注文匯網
#                 </div>
# <div class="footerShare-sys">
# <div class="footerShare-wx">
# <img alt="微信" class="defaul" src="https://wwp-static.wenweipo.com/img/icon/footer-wx.png" title="微信"/>
# <img alt="微信" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wx-hover.png" title="微信"/>
# <div class="wx-img-bottom">
# <img alt="微信" src="https://wwp-static.wenweipo.com/img/icon/wx-share.png" title="微信"/>
# </div>
# </div>
# <a class="footerShare-fb" href="https://zh-hk.facebook.com/wenweipo/" rel="noopener" title="faceBook">
# <img alt="faceBook" class="defaul" src="https://wwp-static.wenweipo.com/img/icon/footer-fb.png" title="faceBook"/>
# <img alt="faceBook" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-fb-hover.png" title="faceBook"/>
# </a>
# <a class="footerShare-wb" href="https://weibo.com/wwpnet" rel="noopener" title="微博">
# <img alt="微博" class="defaul" src="https://wwp-static.wenweipo.com/img/icon/footer-wb.png" title="微博"/>
# <img alt="微博" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wb-hover.png" title="微博"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </footer>
# <div class="rightShareBtn">
# <div class="shareBtn-div" style="display: none;">
# <div class="shareBtn wechat">
# <div class="wx" onclick="showWXimg()" style="cursor: pointer;">
# <img alt="分享到微信" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wx.png" title="分享到微信"/>
# <img alt="分享到微信" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wx-hover.png" title="分享到微信"/>
# </div>
# <div class="wx-img wx-img-share" onclick="closeWXimg()">
# <img alt="分享到微信" src="https://wwp-static.wenweipo.com/img/icon/wx-share.png"/>
# </div>
# </div>
# <div class="shareBtn facebook">
# <a href="https://zh-hk.facebook.com/wenweipo/" rel="noopener" title="分享到facebook">
# <img alt="分享到facebook" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-fb.png" title="分享到facebook"/>
# <img alt="分享到facebook" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-fb-hover.png" title="分享到facebook"/>
# </a>
# </div>
# <div class="shareBtn weibo">
# <a href="https://weibo.com/wwpnet" rel="noopener" title="分享到微博">
# <img alt="分享到微博" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wb.png" title="分享到微博"/>
# <img alt="分享到微博" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-wb-hover.png" title="分享到微博"/>
# </a>
# </div>
# <div class="shareBtn">
# <div class="go-top" target="_self">
# <img alt="回到頂部" class="img" src="https://wwp-static.wenweipo.com/img/icon/right-btn-gotop.png" title="回到頂部"/>
# <img alt="回到頂部" class="hoverImg" src="https://wwp-static.wenweipo.com/img/icon/right-btn-gotop-hover.png" title="回到頂部"/>
# </div>
# </div>
# </div>
# </div>
# <script async="async" src="https://www.googletagmanager.com/gtag/js?id=G-7N6D9S4LRB"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-7N6D9S4LRB');
#       </script>
# <style>
#         .footerShare-wx>img{
#           width:30px;
#         }
#         .yqpar{
#           padding:40px 0;
#           background:#003251;
#           margin-top:36px;
#         }
#         .yq{
#           font-size:16px;
#           display: flex;
#           margin:auto;
#           justify-content: flex-start;
#         }
#         .yq a{
#           color:#cacaca;
#           padding: 0 15px;
#         }
#         .yqleft{
#           color:#CACACA;
#           font-size:20px;
#           padding-right:20px;
#           border-right: 1px solid  #d9d9d9;
#           margin-right:20px
#         }
#         .yqright{
#           padding-left:20px;
#         }
#         .rightb{
#           padding-top:20px;
#         }
#
#         @media (max-width:650px) {
#           .yqpar {
#             padding: 20px 0;
#           }
#           .yq,
#           .rczc{
#             flex-wrap: wrap;
#           }
#           .yqleft{
#             border-right:none;
#             border-bottom:1px solid #d9d9d9;
#             width:100%;
#             margin-right: 0;
#             margin-bottom: 15px;
#             padding-bottom: 5px;
#           }
#           .yq a{
#             padding:0 10px;
#           }
#           .yq a:nth-child(1){
#             padding-left:0;
#           }
#         }
#
#       </style>
# <script charset="utf-8" rel="stylesheet" src="https://www.wenweipo.com/static/wenweipo/js/column/comment.js" type="text/javascript"></script>
# <div class="lightboxOverlay" id="lightboxOverlay" style="display: none;" tabindex="-1"></div><div class="lightbox" id="lightbox" style="display: none;" tabindex="-1"><div class="lb-outerContainer"><div class="lb-container"><img alt="" class="lb-image" src="..."/><div class="lb-nav"><a aria-label="Previous image" class="lb-prev" href=""></a><a aria-label="Next image" class="lb-next" href=""></a></div><div class="lb-loader"><a class="lb-cancel"></a></div></div></div><div class="lb-dataContainer"><div class="lb-data"><div class="lb-details"><span class="lb-caption"></span><span class="lb-number"></span></div><div class="lb-closeContainer"><a class="lb-close"></a></div></div></div></div></body></html>

# %%
content = soup.find_all(class_="searchItem")

for i in content:
    links.append(i.find("a").get("href"))
    topics.append(i.find("a").text)

# %%
if len(links) > 40:
    links = random.sample(links, 40)

# %%
folder_path = "wenweipo/" + date + "/article"

if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
file_name = date + "links.txt"

file = open(direct + date + "/" + file_name, "w", encoding='utf-8')

for i in links:
    file.write(i + "\n")

file.close()

# %%
file_name = date + "topics.txt"

file = open(direct + date + "/" + file_name, "w", encoding='utf-8')

for i in topics:
    file.write(i + "\n")

file.close()

# %%
links = []

file_name = date + "links.txt"

file = open(direct + date + "/" + file_name, "r", encoding='utf-8')

for i in file:
    links.append(i.strip())

links
# Out:
# ['https://www.wenweipo.com/a/202102/02/AP60186659e4b04e1918c491bd.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866a3e4b04e1918c491dd.html',
#  'https://www.wenweipo.com/a/202102/02/AP601865b3e4b04e1918c49148.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186649e4b04e1918c491b7.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186659e4b04e1918c491be.html',
#  'https://www.wenweipo.com/a/202102/02/AP601864dce4b04e1918c490f6.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186560e4b04e1918c4912c.html',
#  'https://www.wenweipo.com/a/202102/02/AP6018655ce4b04e1918c49126.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186540e4b04e1918c49110.html',
#  'https://www.wenweipo.com/a/202102/02/AP601865aee4b04e1918c49147.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186551e4b04e1918c49118.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866e4e4b04e1918c491f4.html',
#  'https://www.wenweipo.com/a/202102/02/AP6018659ae4b04e1918c49143.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186595e4b04e1918c49140.html',
#  'https://www.wenweipo.com/a/202102/02/AP601865dbe4b04e1918c49164.html',
#  'https://www.wenweipo.com/a/202102/02/AP601865cce4b04e1918c49160.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866cce4b04e1918c491ea.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866b7e4b04e1918c491e1.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186699e4b04e1918c491db.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186676e4b04e1918c491d3.html',
#  'https://www.wenweipo.com/a/202102/02/AP6018653be4b04e1918c4910e.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866b2e4b04e1918c491e0.html',
#  'https://www.wenweipo.com/a/202102/02/AP601864d2e4b04e1918c490f3.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866fde4b04e1918c491fc.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186658e4b04e1918c491bc.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866f3e4b04e1918c491fa.html',
#  'https://www.wenweipo.com/a/202102/02/AP601865fee4b04e1918c4916e.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866e5e4b04e1918c491f5.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866e9e4b04e1918c491f6.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186649e4b04e1918c491b6.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186519e4b04e1918c49106.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866f8e4b04e1918c491fb.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186513e4b04e1918c49103.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186680e4b04e1918c491d6.html',
#  'https://www.wenweipo.com/a/202102/02/AP601864e1e4b04e1918c490f8.html',
#  'https://www.wenweipo.com/a/202102/02/AP60186626e4b04e1918c4919c.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866bde4b04e1918c491e6.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866dae4b04e1918c491f0.html',
#  'https://www.wenweipo.com/a/202102/02/AP6018655fe4b04e1918c49128.html',
#  'https://www.wenweipo.com/a/202102/02/AP601866cbe4b04e1918c491e9.html']

# %%
proxy_address = 'brd.superproxy.io'
proxy_port = 22225
proxy_username = 'brd-customer-hl_4abea413-zone-data_center'
proxy_password = 'lmz4ftfwixm4'

proxies = {
    'http': f'http://{proxy_username}:{proxy_password}@{proxy_address}:{proxy_port}',
    'https': f'https://{proxy_username}:{proxy_password}@{proxy_address}:{proxy_port}'
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Referer': 'https://www.google.com/',
    'Connection': 'keep-alive',
    # Add any other headers you want to include
}

# %%
count = 0

for i in links:
    if os.path.exists(direct + date + "/article/" + str(count) + ".txt"):
        count += 1
        continue

    reponse = requests.get(i, proxies=proxies, headers=headers)

    article = BeautifulSoup(reponse.content, "html.parser")

    title = article.find(class_="post-header").find("h1").text

    aspect = article.find(class_="post-header").find("img").get("alt")

    date_and_time = article.find(class_="post-header").find("time").text

    content = [j.text for j in article.find_all("p")]

    file_name = str(count) + ".txt"

    file = open("wenweipo/"+ date  + "/article/" + file_name, "w", encoding='utf-8')

    file.write(title + "\n")

    file.write(aspect + "\n")

    file.write(date_and_time + "\n")

    for j in content:
        file.write(j + "\n")

    file.write(i)

    file.close()

    time.sleep(30*random.uniform(1, 1.5))

    count += 1
